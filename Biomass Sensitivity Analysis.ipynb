# %%
import cobra
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from cobra.flux_analysis import single_gene_deletion
from molmass import Formula

# %matplotlib inline

# %%
model=cobra.io.read_sbml_model('/Users/amit/Desktop/Mac/ScientificReports/Lachancea-kluyveri-iPN730-master/iPN730.xml')
model.solver='glpk'
model.reactions.EX_cpd00092_e0.bounds=(0,1000)
model.reactions.EX_cpd19013_e0.bounds=(-1000,1000)
model.reactions.EX_cpd00027_e0.bounds=(-2.28,1000)
model.reactions.EX_cpd00007_e0.bounds=(-10,1000)
model.summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">IN_FLUXES</th>
#       <th colspan="2" halign="left">OUT_FLUXES</th>
#       <th colspan="2" halign="left">OBJECTIVES</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>o2_e</td>
#       <td>5.594380</td>
#       <td>h2o_e</td>
#       <td>8.319454</td>
#       <td>bio1</td>
#       <td>0.22224</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>cpd19013_e0</td>
#       <td>2.298529</td>
#       <td>co2_e</td>
#       <td>5.238594</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>glc-D_e</td>
#       <td>2.280000</td>
#       <td>h_e</td>
#       <td>1.010835</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>urea_e</td>
#       <td>0.527386</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
bio=model.reactions.get_by_id('bio1')
met_pc=bio.metabolites
met_names=[]
met_coeff=[]
met_formula=[]
met_chemnames=[]
for met in met_pc:
    met_names.append(met.id)
    met_coeff.append(met_pc[met])
    met_chemnames.append(met.name)
    met_formula.append(met.formula)
met_formula[1]='C4140H7644O1300P100'
met_formula[9]='C3736H7172N100O1000P100'
met_formula[10]='C3636H7172N100O800P100'

# %%
def cnratio(modelg):
    nh4=np.linspace(0.1,2.27,20)
    cn=((6*2.26)/(1*nh4)*(12/14))
    fit=[]
    for n in nh4:
        modelg.reactions.EX_cpd19013_e0.bounds=(-n,1000)
        fit.append(modelg.slim_optimize())
    cnval=cn[fit.index(max(fit))]
    return [cnval,max(fit)]

# %%
def gr(p,metc,metn):
    if(metc<0):
        
        #Increase
        modelf=model.copy()
        biof=modelf.reactions.get_by_id('bio1')
        biof.add_metabolites({modelf.metabolites.get_by_id(metn):p*(-metc)})
        gr_plus10=modelf.slim_optimize()
        sgd_minimal=single_gene_deletion(model,method='FBA')
        sgd_minimal['SimulationTruth']=sgd_minimal['growth'].apply(lambda x:'Growth' if (round(x,5)!=0) else 'No Growth')
        ess_genp10=sgd_minimal[sgd_minimal['SimulationTruth']=='No Growth'].count()['growth']
        
#         optgr_p10=cnratio(modelf)
        
        #Decrease
        modelf=model.copy()
        biof=modelf.reactions.get_by_id('bio1')
        biof.add_metabolites({modelf.metabolites.get_by_id(metn):p*(metc)})
        gr_minus10=modelf.slim_optimize()
        sgd_minimal=single_gene_deletion(model,method='FBA')
        sgd_minimal['SimulationTruth']=sgd_minimal['growth'].apply(lambda x:'Growth' if (round(x,5)!=0) else 'No Growth')
        ess_genm10=sgd_minimal[sgd_minimal['SimulationTruth']=='No Growth'].count()['growth']
        #         optgr_m10=cnratio(modelf)
        
        return gr_plus10,gr_minus10,ess_genp10,ess_genm10

# %%
def atomcount(formula,e):
    f=Formula(formula)
    get=list(f.composition())
    d=pd.DataFrame(get,columns=['Element','Count','Bla1','Bla2'])
    d.index=d['Element']
    return d['Count'][e]

# %%
p=50
p=p/100
p10=[]
m10=[]
ess_p10=[]
ess_m10=[]
for metn,metc in zip(met_names,met_coeff):
    print('Current Biomass Precursor: ',metn)
    grp10,grm10,essp10,essm10=gr(p,metc,metn)
    p10.append(grp10)
    m10.append(grm10)
    ess_p10.append(essp10)
    ess_m10.append(essm10)
    print('Increase-Growth Rate: ',grp10)
    print('Decrease-Growth Rate: ',grm10)
    print('Increase-Essential Genes: ',essp10)
    print('Decrease-Essential Genes: ',essm10)
# Out:
# Current Biomass Precursor:  13BDglcn_c
# Increase-Growth Rate:  0.2368825462416903
# Decrease-Growth Rate:  0.20930240752263135
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  M_ptd1ino_SC_c_c0
# Increase-Growth Rate:  0.2228959088237305
# Decrease-Growth Rate:  0.22158807526154892
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  ala-L_c
# Increase-Growth Rate:  0.22452885760376834
# Decrease-Growth Rate:  0.21999747016153082
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  amp_c
# Increase-Growth Rate:  0.22321269710528818
# Decrease-Growth Rate:  0.22127587837025386
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  arg-L_c
# Increase-Growth Rate:  0.22447647800382686
# Decrease-Growth Rate:  0.2200477801072813
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  asn-L_c
# Increase-Growth Rate:  0.2230040447579184
# Decrease-Growth Rate:  0.22148130786236
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  asp-L_c
# Increase-Growth Rate:  0.22391107857155834
# Decrease-Growth Rate:  0.22059381358042884
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  atp_c
# Increase-Growth Rate:  -5.914302799904129e-16
# Decrease-Growth Rate:  0.031667037504342375
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  cmp_c
# Increase-Growth Rate:  0.22288188568732628
# Decrease-Growth Rate:  0.22159639324237007
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  cpd29687_c0
# Increase-Growth Rate:  0.2224387530702812
# Decrease-Growth Rate:  0.22204173751221642
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  cpd29688_c0
# Increase-Growth Rate:  0.22276605449318107
# Decrease-Growth Rate:  0.221716559496653
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  cys-L_c
# Increase-Growth Rate:  0.22231210342284866
# Decrease-Growth Rate:  0.22216807920830922
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  damp_c
# Increase-Growth Rate:  0.2223190369666253
# Decrease-Growth Rate:  0.22216115507713483
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  dcmp_c
# Increase-Growth Rate:  0.22226842407372213
# Decrease-Growth Rate:  0.22221171912367754
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  dgmp_c
# Increase-Growth Rate:  0.22229366389504943
# Decrease-Growth Rate:  0.22218649790632808
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  dtmp_c
# Increase-Growth Rate:  0.22229264399316434
# Decrease-Growth Rate:  0.22218751683442442
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  ergst_c
# Increase-Growth Rate:  0.2223235187631647
# Decrease-Growth Rate:  0.22215667982428625
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  gln-L_c
# Increase-Growth Rate:  0.2231757519890936
# Decrease-Growth Rate:  0.22131219709225125
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  glu-L_c
# Increase-Growth Rate:  0.22474365394409784
# Decrease-Growth Rate:  0.21979164610097102
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  gly_c
# Increase-Growth Rate:  0.223069229635173
# Decrease-Growth Rate:  0.22138761532491033
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  glycogen_c
# Increase-Growth Rate:  0.2286992220868143
# Decrease-Growth Rate:  0.2161357442884046
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  gmp_c
# Increase-Growth Rate:  0.22323117692922087
# Decrease-Growth Rate:  0.22125772084768008
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  h2o_c
# Increase-Growth Rate:  0.22224006798160792
# Decrease-Growth Rate:  0.22224006798160792
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  his-L_c
# Increase-Growth Rate:  0.22319104478755045
# Decrease-Growth Rate:  0.22129716067445176
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  ile-L_c
# Increase-Growth Rate:  0.22502155785333922
# Decrease-Growth Rate:  0.2195265024505188
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  leu-L_c
# Increase-Growth Rate:  0.2263513378533475
# Decrease-Growth Rate:  0.21827548168795544
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  lys-L_c
# Increase-Growth Rate:  0.2263254655859874
# Decrease-Growth Rate:  0.2182995461296548
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  mannan_c
# Increase-Growth Rate:  0.23247034432465746
# Decrease-Growth Rate:  0.21287224146474584
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  met-L_c
# Increase-Growth Rate:  0.22308719297371393
# Decrease-Growth Rate:  0.221399352196976
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  pa_SC_c
# Increase-Growth Rate:  0.22230819118232417
# Decrease-Growth Rate:  0.22217198651888462
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  pc_SC_c
# Increase-Growth Rate:  0.2230270842015779
# Decrease-Growth Rate:  0.22145858666341292
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  phe-L_c
# Increase-Growth Rate:  0.2249020372767864
# Decrease-Growth Rate:  0.21964037637818748
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  pro-L_c
# Increase-Growth Rate:  0.22397178456311323
# Decrease-Growth Rate:  0.2205349246903126
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  ribflv_c
# Increase-Growth Rate:  0.22228044414243972
# Decrease-Growth Rate:  0.22219970648637838
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  ser-L_c
# Increase-Growth Rate:  0.22314443399619666
# Decrease-Growth Rate:  0.22134300285761307
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  so4_c
# Increase-Growth Rate:  0.22224006798160792
# Decrease-Growth Rate:  0.22224006798160792
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  thr-L_c
# Increase-Growth Rate:  0.2238677061222121
# Decrease-Growth Rate:  0.22063592660920064
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  tre_c
# Increase-Growth Rate:  0.22279307145544963
# Decrease-Growth Rate:  0.22168980297399626
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  triglyc_SC_c
# Increase-Growth Rate:  0.22333628474996273
# Decrease-Growth Rate:  0.2211545599225125
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  trp-L_c
# Increase-Growth Rate:  0.22295483482558795
# Decrease-Growth Rate:  0.22152986940830413
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  tyr-L_c
# Increase-Growth Rate:  0.22417113179474948
# Decrease-Growth Rate:  0.22034198931874782
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  ump_c
# Increase-Growth Rate:  0.22289715960096476
# Decrease-Growth Rate:  0.22158683913286564
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  val-L_c
# Increase-Growth Rate:  0.22488423661827003
# Decrease-Growth Rate:  0.21965735653110535
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  zymst_c
# Increase-Growth Rate:  0.22240811965987362
# Decrease-Growth Rate:  0.22207227007144908
# Increase-Essential Genes:  119
# Decrease-Essential Genes:  119
# Current Biomass Precursor:  adp_c
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-61d8e6b06083> in <module>
#       7 for metn,metc in zip(met_names,met_coeff):
#       8     print('Current Biomass Precursor: ',metn)
# ----> 9     grp10,grm10,essp10,essm10=gr(p,metc,metn)
#      10     p10.append(grp10)
#      11     m10.append(grm10)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
df_sorted=pd.DataFrame({"Name":pd.Series(met_chemnames[:44]),"Increase":p10,"Decrease":m10,"Formula":met_formula[:44],'Coeff':met_coeff[:44]})
df_sorted['Diff']=df_sorted['Increase']-df_sorted['Decrease']
df_sorted['Formula']=df_sorted['Formula'].apply(lambda x: x[0:x.index('R')] if ('R' in x) else x)
df_sorted=df_sorted.sort_values(by='Diff',ascending=False)
df_sorted=df_sorted.reset_index(drop=True)

# %%
#CountC/NRatio
df_sorted['C']=df_sorted['Formula'].apply(lambda x:(atomcount(x,'C')) if ('C' in x) else 0)
df_sorted['N']=df_sorted['Formula'].apply(lambda x:(atomcount(x,'N')) if ('N' in x) else 0)
df_sorted['Cmols']=df_sorted['C']*abs(df_sorted['Coeff'])
df_sorted['Nmols']=df_sorted['N']*abs(df_sorted['Coeff'])

# %%
import matplotlib.ticker as ticker
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(12,20))
ax.bar(df_sorted['Name'],df_sorted['Diff'],bottom=df_sorted['Decrease'],color='r')
ax.set_ylabel('Biomass Precursors',fontsize=14)
ax.set_xlabel('Growth rate (1/hr)',fontsize=14)
ax.set_xlim([0.205,0.24])
plt.yticks(np.arange(0,44,1),rotation=40)
ax.set_yticklabels(met_chemnames,fontsize=16)
ax.plot(df_sorted['Increase'],'bo')
ax.plot(df_sorted['Decrease'],'yo')
plt.gca().invert_xaxis()

# %%
fig.savefig("D:/ScientificReports/BiomassSensitivityNames.jpg",dpi=1200)

# %%
df_sorted['CmolsInc']=df_sorted['Cmols']*1.5
df_sorted['CmolsDec']=df_sorted['Cmols']*0.5
df_sorted['NmolsInc']=df_sorted['Nmols']*1.5
df_sorted['NmolsDec']=df_sorted['Nmols']*0.5

df_sorted['C/NInc']=pd.Series()
df_sorted['C/NDec']=pd.Series()

for i in range(len(df_sorted)):
    df_sorted['C/NInc'][i]=(df_sorted['Cmols'].sum()+(df_sorted['CmolsInc'][i]-df_sorted['Cmols'][i]))/(df_sorted['Nmols'].sum()+(df_sorted['NmolsInc'][i]-df_sorted['Nmols'][i]))
    df_sorted['C/NDec'][i]=(df_sorted['Cmols'].sum()+(df_sorted['Cmols'][i]-df_sorted['CmolsDec'][i]))/(df_sorted['Nmols'].sum()+(df_sorted['Nmols'][i]-df_sorted['NmolsDec'][i]))

# %%
df_sorted

# %%
cobra.io.write_sbml_model(model,"D:/ScientificReports/iPN730.xml")
